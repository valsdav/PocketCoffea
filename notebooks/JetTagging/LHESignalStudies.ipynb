# %%
import sys
sys.path.append("../../")

import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import mplhep as hep
from coffea.util import load
import numpy as np
import pandas as pd
import awkward as ak
from coffea.nanoevents import NanoEventsFactory, NanoAODSchema

from pprint import pprint 
hep.style.use(hep.style.ROOT)

import matplotlib as mtp
mtp.rcParams['figure.dpi'] = 72

import hist

# %% [markdown]
# ## Loading

# %%
file = "../../config/lhe_signal_studies/test/output.coffea"
out = load(file)
out.keys()
# Out:
# dict_keys(['sum_genweights', 'sumw', 'cutflow', 'seed_chunk', 'variables', 'columns', 'processing_metadata', 'scale_genweight'])

# %%
out["variables"].keys()
# Out:
# dict_keys(['allEle_eta_1', 'allEle_pt_1', 'allEle_phi_1', 'allEle_eta_2', 'allEle_pt_2', 'allEle_phi_2', 'allMuon_eta_1', 'allMuon_pt_1', 'allMuon_phi_1', 'allMuon_eta_2', 'allMuon_pt_2', 'allMuon_phi_2', 'ElectronGood_eta_1', 'ElectronGood_pt_1', 'ElectronGood_phi_1', 'ElectronGood_eta_2', 'ElectronGood_pt_2', 'ElectronGood_phi_2', 'MuonGood_eta_1', 'MuonGood_pt_1', 'MuonGood_phi_1', 'MuonGood_eta_2', 'MuonGood_pt_2', 'MuonGood_phi_2', 'LHE_Electron_eta_1', 'LHE_Electron_pt_1', 'LHE_Electron_phi_1', 'LHE_Electron_eta_2', 'LHE_Electron_pt_2', 'LHE_Electron_phi_2', 'LHE_Muon_eta_1', 'LHE_Muon_pt_1', 'LHE_Muon_phi_1', 'LHE_Muon_eta_2', 'LHE_Muon_pt_2', 'LHE_Muon_phi_2', 'LHE_matched_ele_eta_1', 'LHE_matched_ele_pt_1', 'LHE_matched_ele_phi_1', 'LHE_matched_ele_eta_2', 'LHE_matched_ele_pt_2', 'LHE_matched_ele_phi_2', 'LHE_matched_muon_eta_1', 'LHE_matched_muon_pt_1', 'LHE_matched_muon_phi_1', 'LHE_matched_muon_eta_2', 'LHE_matched_muon_pt_2', 'LHE_matched_muon_phi_2', 'lhe_matched_ele_1_
# ...

# %%
h
# Out:
# Hist(
#   StrCategory(['0lep_dilep', '0lep_had', '0lep_semilep', '1ele', '1ele_dilep', '1ele_had', '1ele_semilep', '1lep_dilep', '1lep_had', '1lep_semilep', '1mu', '1mu_dilep', '1mu_had', '1mu_semilep', '2lep_dilep', '2lep_had', '2lep_semilep', 'semilep_presel'], name='cat', label='Category'),
#   StrCategory(['nominal'], name='variation', label='Variation'),
#   StrCategory(['2018'], name='year', label='Year'),
#   Regular(200, 0, 1000, name='ElectronGood.pt', label='$p_{T}^{e}$ [GeV]'),
#   storage=Weight()) # Sum: WeightedSum(value=101.871, variance=0.37347)

# %%
h = out["variables"]["nlepton_lhe"]["ttHTobb"]
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="semilep")
hep.histplot(h[{"cat":"1lep_had", "year":"2018", "variation":"nominal"}], label="had")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep notau")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep onetau")
hep.histplot(h[{"cat":"1lep_dilep_twotau", "year":"2018", "variation":"nominal"}], label="dilep twotau")
plt.legend()
#plt.yscale("log")
plt.text(2.2,0.7,"1 reco Lepton \n$p_T>26 GeV$")
# Out:
# Text(2.2, 0.7, '1 reco Lepton \n$p_T>26 GeV$')

# %%
h = out["variables"]["nlepton_lhe"]["ttHTobb"]
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="semilep")
hep.histplot(h[{"cat":"1lep_had", "year":"2018", "variation":"nominal"}], label="had")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep no tau")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep one tau")
plt.legend()
#plt.yscale("log")
plt.text(2.2,0.7,"1 reco Lepton \n$p_T>26 GeV$")
# Out:
# Text(2.2, 0.7, '1 reco Lepton \n$p_T>26 GeV$')

# %%
h = out["variables"]["nlepton_lhe"]["ttHTobb"]
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="semilep", density=True)
hep.histplot(h[{"cat":"1lep_had", "year":"2018", "variation":"nominal"}], label="had",density=True)
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep",density=True)
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep no tau",density=True)
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep one tau",density=True)
plt.legend()
#plt.yscale("log")
plt.text(2.2,0.7,"1 reco Lepton \n$p_T>26 GeV$")
# Out:
# Text(2.2, 0.7, '1 reco Lepton \n$p_T>26 GeV$')

# %%
h = out["variables"]["nele_lhe"]["ttHTobb"]
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="semilep", density=True)
hep.histplot(h[{"cat":"1ele_had", "year":"2018", "variation":"nominal"}], label="had",density=True)
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="dilep",density=True)
plt.legend()
#plt.yscale("log")
plt.text(2.2,0.7,"1 reco Electron \n$p_T>30 GeV$")
# Out:
# Text(2.2, 0.7, '1 reco Electron \n$p_T>30 GeV$')

# %%
h = out["variables"]["LHE_Electron_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="semilep")
hep.histplot(h[{"cat":"1ele_semilep_notau", "year":"2018", "variation":"nominal"}], label="semilep no tau")
hep.histplot(h[{"cat":"1ele_had", "year":"2018", "variation":"nominal"}], label="had")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep no tau")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep one tau")
plt.legend()
#plt.yscale("log")
plt.xlim(0, 120)
plt.text(0.5, 0.5,"1 reco Electron \n$p_T>30 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the leading electron parton")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, 'Pt of the leading electron parton')

# %%
h = out["variables"]["LHE_Lepton_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="semilep")
hep.histplot(h[{"cat":"1lep_semilep_notau", "year":"2018", "variation":"nominal"}], label="semilep notau")
hep.histplot(h[{"cat":"1lep_had", "year":"2018", "variation":"nominal"}], label="had")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep no tau")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep one tau")
hep.histplot(h[{"cat":"1lep_dilep_twotau", "year":"2018", "variation":"nominal"}], label="dilep two tau")
plt.legend()
#plt.yscale("log")
plt.xlim(0, 120)
plt.text(0.2, 0.5,"1 reco lepton\n$p_T>26 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the leading parton")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, 'Pt of the leading parton')

# %% [markdown]
# ## Pt of the second lepton at LHE level

# %%
h = out["variables"]["LHE_Lepton_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="presel")
hep.histplot(h[{"cat":"presel_semilep", "year":"2018", "variation":"nominal"}], label="presel , semilep LHE")
hep.histplot(h[{"cat":"presel_dilep_notau", "year":"2018", "variation":"nominal"}], label="presel, dilep LHE no tau")
hep.histplot(h[{"cat":"presel_dilep_onetau", "year":"2018", "variation":"nominal"}], label="presel, dilep LHE one tau")
plt.legend()
#plt.yscale("log")
plt.xlim(0, 120)
plt.text(0.6, 0.3,"only 1 reco lepton\n$p_T>26 GeV$\nveto second", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading parton lepton")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, 'Pt of the subleading parton lepton')

# %%
h = out["variables"]["LHE_Lepton_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="semilep")
hep.histplot(h[{"cat":"1lep_semilep_notau", "year":"2018", "variation":"nominal"}], label="semilep notau")
hep.histplot(h[{"cat":"1lep_had", "year":"2018", "variation":"nominal"}], label="had")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep no tau")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep one tau")
hep.histplot(h[{"cat":"1lep_dilep_twotau", "year":"2018", "variation":"nominal"}], label="dilep two tau")
plt.legend()
#plt.yscale("log")
plt.xlim(0, 120)
plt.text(0.6, 0.3,"only 1 reco lepton\n$p_T>26 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading parton lepton")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, 'Pt of the subleading parton lepton')

# %%
h = out["variables"]["LHE_Tau_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="semilep")
hep.histplot(h[{"cat":"1lep_semilep_notau", "year":"2018", "variation":"nominal"}], label="semilep notau")
hep.histplot(h[{"cat":"1lep_had", "year":"2018", "variation":"nominal"}], label="had")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep no tau")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep one tau")
hep.histplot(h[{"cat":"1lep_dilep_twotau", "year":"2018", "variation":"nominal"}], label="dilep two tau")
plt.legend()
#plt.yscale("log")
plt.xlim(0, 120)
plt.text(0.2, 0.5,"1 reco lepton\n$p_T>26 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the leading tau parton")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, 'Pt of the leading tau parton')

# %%
h = out["variables"]["LHE_Tau_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="semilep")
hep.histplot(h[{"cat":"1ele_had", "year":"2018", "variation":"nominal"}], label="had")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="dilep no tau")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="dilep one tau")
hep.histplot(h[{"cat":"1ele_dilep_twotau", "year":"2018", "variation":"nominal"}], label="dilep two tau")
plt.legend()
#plt.yscale("log")
plt.xlim(0, 120)
plt.text(0.5, 0.5,"1 reco Electron \n$p_T>30 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the leading electron parton")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, 'Pt of the leading electron parton')

# %%
h = out["variables"]["LHE_Muon_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1mu", "year":"2018", "variation":"nominal"}], label="single mu sel")
hep.histplot(h[{"cat":"1mu_dilep", "year":"2018", "variation":"nominal"}], label="single mu sel + dilep")
hep.histplot(h[{"cat":"1mu_dilep_notau", "year":"2018", "variation":"nominal"}], label="single mu sel + dilep + notau")
hep.histplot(h[{"cat":"1mu_dilep_onetau", "year":"2018", "variation":"nominal"}], label="single mu sel + dilep + onetau")
plt.legend()
#plt.yscale("log")
plt.text(0.5, 0.5,"1 reco Electron \n$p_T>30 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading electron parton")
plt.xlim(0,100)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 100.0)

# %%
h = out["variables"]["LHE_Electron_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="single ele sel")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + notau")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + onetau")
plt.legend()
#plt.yscale("log")
plt.text(0.5, 0.5,"1 reco Electron \n$p_T>30 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading electron parton")
plt.xlim(0,100)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 100.0)

# %%
h = out["variables"]["LHE_Muon_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="single ele sel")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + notau")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + onetau")
plt.legend()
#plt.yscale("log")
plt.text(0.5, 0.5,"1 reco Electron \n$p_T>26 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading muon parton")
plt.xlim(0,100)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 100.0)

# %%
h = out["variables"]["LHE_Electron_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1mu", "year":"2018", "variation":"nominal"}], label="single ele sel")
hep.histplot(h[{"cat":"1mu_dilep", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep")
hep.histplot(h[{"cat":"1mu_dilep_notau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + notau")
hep.histplot(h[{"cat":"1mu_dilep_onetau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + onetau")
plt.legend()
#plt.yscale("log")
plt.text(0.5, 0.5,"1 reco Muon \n$p_T>26 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading electron parton")
plt.xlim(0,100)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 100.0)

# %%
h = out["variables"]["LHE_Tau_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="single ele sel")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + notau")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="single ele sel + dilep + onetau")
plt.legend()
#plt.yscale("log")
plt.text(0.5, 0.5,"1 reco Electron \n$p_T>30 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading electron parton")
plt.xlim(0,300)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 300.0)

# %%
h = out["variables"]["LHE_Electron_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"2lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep")
plt.legend()
#plt.yscale("log")
plt.text(0.5, 0.5,"2 reco Lepton \n$p_T>15 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading electron parton")
plt.xlim(0,200)
# Out:
# (0.0, 200.0)

# %%
h = out["variables"]["LHE_Electron_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele + semilep LHE")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele + dilep LHE")
plt.legend()
#plt.yscale("log")
plt.text(0.5, 0.5,"1 reco Electron \n$p_T>30 GeV$", transform=plt.gca().transAxes)
plt.xlabel("Pt of the subleading electron parton")
plt.xlim(0,300)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 300.0)

# %% [markdown]
# ## Number of leptons

# %%
h = out["variables"]["nlepton_incl"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="presel")
hep.histplot(h[{"cat":"presel_semilep", "year":"2018", "variation":"nominal"}], label="presel, semilep LHE")
hep.histplot(h[{"cat":"presel_dilep_notau", "year":"2018", "variation":"nominal"}], label="presel, dilep LHE notau")
hep.histplot(h[{"cat":"presel_dilep_onetau", "year":"2018", "variation":"nominal"}], label="presel, dilep LHE onetau")
#plt.text(0.6, 0.3,"only 1 reco lepton\n$p_T>26 GeV$", transform=plt.gca().transAxes)
plt.legend()
#plt.yscale("log")
plt.xlabel("Number of reco lepton passing presel")
plt.xlim(0, 5)
print(f"Number of events with 1 reco lepton in dilepton no tau LHE events: ", h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}][1])
print(f"Number of events with 1 reco lepton in dilepton with tau LHE events: ", h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}][1])
# Out:
# Number of events with 1 reco lepton in dilepton no tau LHE events:  WeightedSum(value=293.253, variance=0.548271)
# Number of events with 1 reco lepton in dilepton with tau LHE events:  WeightedSum(value=348.827, variance=0.651484)

# %%
h = out["variables"]["nlepton_incl"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="full presel with veto")
hep.histplot(h[{"cat":"1lep", "year":"2018", "variation":"nominal"}], label="1lep")
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="1lep + semilep LHE")
hep.histplot(h[{"cat":"1lep_semilep_notau", "year":"2018", "variation":"nominal"}], label="1lep + semilep LHE notau")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="1lep+ dilep LHE")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="1lep+ dilep notau LHE")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1lep+ dilep one tau LHE")
hep.histplot(h[{"cat":"1lep_dilep_twotau", "year":"2018", "variation":"nominal"}], label="1lep+ dilep two tau LHE")
#plt.text(0.6, 0.3,"only 1 reco lepton\n$p_T>26 GeV$", transform=plt.gca().transAxes)
plt.legend()
#plt.yscale("log")
plt.xlabel("Number of reco lepton passing presel")
plt.xlim(0, 5)
print(f"Number of events with 1 reco lepton in dilepton no tau LHE events: ", h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}][1])
print(f"Number of events with 1 reco lepton in dilepton with tau LHE events: ", h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}][1])
# Out:
# Number of events with 1 reco lepton in dilepton no tau LHE events:  WeightedSum(value=293.253, variance=0.548271)
# Number of events with 1 reco lepton in dilepton with tau LHE events:  WeightedSum(value=348.827, variance=0.651484)

# %%
h = out["variables"]["nele_incl"]["ttHTobb"]
plt.figure(dpi=72)

#hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="full presel with veto")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1ele")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1ele + semilep LHE")
hep.histplot(h[{"cat":"1ele_semilep_notau", "year":"2018", "variation":"nominal"}], label="1ele + semilep notau LHE")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1ele+ dilep LHE")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="1ele+ dilep notau LHE")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1ele+ dilep one tau LHE")
plt.legend()
#plt.yscale("log")
#plt.text(0.5, 0.5,"semilep presel (4 Jets, 3 btag)", transform=plt.gca().transAxes)
plt.xlabel("nElectrons")
plt.xlim(0, 5)

print(f"Number of events with 1 reco electron in dilepton no tau LHE events: ", h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}][1])
print(f"Number of events with 1 reco electron in dilepton with tau LHE events: ", h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}][1])
# Out:
# Number of events with 1 reco electron in dilepton no tau LHE events:  WeightedSum(value=146.393, variance=0.265843)
# Number of events with 1 reco electron in dilepton with tau LHE events:  WeightedSum(value=145.763, variance=0.265216)

# %%
h = out["variables"]["nmuon_incl"]["ttHTobb"]
plt.figure(dpi=72)

#hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="full presel with veto")
hep.histplot(h[{"cat":"1mu", "year":"2018", "variation":"nominal"}], label="1mu")
hep.histplot(h[{"cat":"1mu_semilep", "year":"2018", "variation":"nominal"}], label="1mu + semilep LHE")
hep.histplot(h[{"cat":"1muon_semilep_notau", "year":"2018", "variation":"nominal"}], label="1mu + semilep notau LHE")
hep.histplot(h[{"cat":"1mu_dilep", "year":"2018", "variation":"nominal"}], label="1mu+ dilep LHE")
hep.histplot(h[{"cat":"1mu_dilep_notau", "year":"2018", "variation":"nominal"}], label="1mu+ dilep notau LHE")
hep.histplot(h[{"cat":"1mu_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1mu+ dilep one tau LHE")
plt.legend()
#plt.yscale("log")
#plt.text(0.5, 0.5,"semilep presel (4 Jets, 3 btag)", transform=plt.gca().transAxes)
plt.xlabel("nMuons")
plt.xlim(0, 5)

print(f"Number of events with 1 reco electron in dilepton no tau LHE events: ", h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}][1])
print(f"Number of events with 1 reco electron in dilepton with tau LHE events: ", h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}][1])
# Out:
# Number of events with 1 reco electron in dilepton no tau LHE events:  WeightedSum(value=206.578, variance=0.388924)
# Number of events with 1 reco electron in dilepton with tau LHE events:  WeightedSum(value=222.456, variance=0.421015)

# %%
h = out["variables"]["LeptonGood_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"1lep", "year":"2018", "variation":"nominal"}], label="1lep")
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="1lep+semilep lhe")
hep.histplot(h[{"cat":"1lep_semilep_notau", "year":"2018", "variation":"nominal"}], label="1lep+semilep notau lhe")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="1lep+dilep lhe")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="1lep+dilep notau lhe")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1lep+dilep onetau lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Leading Lepton pt 1")
# Out:
# Text(1, 0, 'Leading Lepton pt 1')

# %%
h = out["variables"]["LeptonGood_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="presel (veto)")
hep.histplot(h[{"cat":"1lep", "year":"2018", "variation":"nominal"}], label="1lep")
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="1lep+semilep lhe")
hep.histplot(h[{"cat":"1lep_semilep_notau", "year":"2018", "variation":"nominal"}], label="1lep+semilep notau lhe")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="1lep+dilep lhe")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="1lep+dilep notau lhe")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1lep+dilep onetau lhe")
hep.histplot(h[{"cat":"1lep_dilep_twotau", "year":"2018", "variation":"nominal"}], label="1lep+dilep twotau lhe")
plt.legend()
#plt.yscale("log")
plt.xlabel("Subleading Lepton pt")
plt.xlim(0,60)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 60.0)

# %%
h = out["variables"]["ElectronGood_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1ele")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1ele+semilep lhe")
hep.histplot(h[{"cat":"1ele_semilep_notau", "year":"2018", "variation":"nominal"}], label="1ele+semilep notau lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1ele+dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Leading Electron pt 1")
# Out:
# Text(1, 0, 'Leading Electron pt 1')

# %%
h = out["variables"]["ElectronGood_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="presel (veto)")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1ele")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1ele+semilep lhe")
hep.histplot(h[{"cat":"1ele_semilep_notau", "year":"2018", "variation":"nominal"}], label="1ele+semilep notau lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1ele+dilep lhe")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1ele+dilep lhe onetau")
hep.histplot(h[{"cat":"1ele_dilep_twotau", "year":"2018", "variation":"nominal"}], label="1ele+dilep lhe twotau")
plt.legend()
#plt.yscale("log")
plt.xlabel("Leading Electron pt 2")
plt.xlim(0,50)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 50.0)

# %%
h = out["variables"]["ElectronGood_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Ele leading pt")
plt.xlim(0, 200)
# Out:
# (0.0, 200.0)

# %%
h = out["variables"]["LHE_Electron_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Ele LHE leading pt")
plt.xlim(0, 200)
# Out:
# (0.0, 200.0)

# %%
h = out["variables"]["LHE_Electron_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Ele LHE subleading pt")
plt.xlim(0, 200)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 200.0)

# %%
h = out["variables"]["ElectronGood_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1ele semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1ele dilep lhe")
hep.histplot(h[{"cat":"2lep", "year":"2018", "variation":"nominal"}], label="2 Leptons 30,15 GeV")
hep.histplot(h[{"cat":"2lep_semilep", "year":"2018", "variation":"nominal"}], label="2lep semilep lhe")
hep.histplot(h[{"cat":"2lep_dilep", "year":"2018", "variation":"nominal"}], label="2lep dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Ele subleading pt")
plt.xlim(0, 200)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 200.0)

# %%
h = out["variables"]["ElectronGood_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"2lep", "year":"2018", "variation":"nominal"}], label="2 Leptons 30,15 GeV")
hep.histplot(h[{"cat":"2lep_semilep", "year":"2018", "variation":"nominal"}], label="semilep lhe")
hep.histplot(h[{"cat":"2lep_dilep", "year":"2018", "variation":"nominal"}], label="dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Subleading ele pt")
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
h = out["variables"]["nlepton_lhe"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
# hep.histplot(h[{"cat":"2lep", "year":"2018", "variation":"nominal"}], label="2 lep reco (30,15 GeV)")
# hep.histplot(h[{"cat":"2lep_semilep", "year":"2018", "variation":"nominal"}], label="2 lep reco (30,15 GeV) - semilep lhe")
# hep.histplot(h[{"cat":"2lep_dilep", "year":"2018", "variation":"nominal"}], label="2 lep reco (30,15 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("n. Ele LHE")
# Out:
# Text(1, 0, 'n. Ele LHE')

# %%
h = out["variables"]["nele_lhe"]["ttHTobb"]

#hep.histplot(h[{"cat":"semilep_presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
# hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
# hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
# hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"2lep", "year":"2018", "variation":"nominal"}], label="2 lep reco (30,15 GeV)")
hep.histplot(h[{"cat":"2lep_semilep", "year":"2018", "variation":"nominal"}], label="2 lep reco (30,15 GeV) - semilep lhe")
hep.histplot(h[{"cat":"2lep_dilep", "year":"2018", "variation":"nominal"}], label="2 lep reco (30,15 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("n. Ele LHE")
# Out:
# Text(1, 0, 'n. Ele LHE')

# %%
h = out["variables"]["nmuon_lhe"]["ttHTobb"]

#hep.histplot(h[{"cat":"semilep_presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1mu", "year":"2018", "variation":"nominal"}], label="1 muon reco (30 GeV)")
hep.histplot(h[{"cat":"1mu_semilep", "year":"2018", "variation":"nominal"}], label="1 muon reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1mu_dilep", "year":"2018", "variation":"nominal"}], label="1 muon reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("n. Ele LHE")
# Out:
# Text(1, 0, 'n. Ele LHE')

# %%
out["variables"].keys()
# Out:
# dict_keys(['allEle_eta_1', 'allEle_pt_1', 'allEle_phi_1', 'allEle_eta_2', 'allEle_pt_2', 'allEle_phi_2', 'allMuon_eta_1', 'allMuon_pt_1', 'allMuon_phi_1', 'allMuon_eta_2', 'allMuon_pt_2', 'allMuon_phi_2', 'ElectronGood_eta_1', 'ElectronGood_pt_1', 'ElectronGood_phi_1', 'ElectronGood_eta_2', 'ElectronGood_pt_2', 'ElectronGood_phi_2', 'MuonGood_eta_1', 'MuonGood_pt_1', 'MuonGood_phi_1', 'MuonGood_eta_2', 'MuonGood_pt_2', 'MuonGood_phi_2', 'LHE_Electron_eta_1', 'LHE_Electron_pt_1', 'LHE_Electron_phi_1', 'LHE_Electron_eta_2', 'LHE_Electron_pt_2', 'LHE_Electron_phi_2', 'LHE_Muon_eta_1', 'LHE_Muon_pt_1', 'LHE_Muon_phi_1', 'LHE_Muon_eta_2', 'LHE_Muon_pt_2', 'LHE_Muon_phi_2', 'LHE_matched_ele_eta_1', 'LHE_matched_ele_pt_1', 'LHE_matched_ele_phi_1', 'LHE_matched_ele_eta_2', 'LHE_matched_ele_pt_2', 'LHE_matched_ele_phi_2', 'LHE_matched_muon_eta_1', 'LHE_matched_muon_pt_1', 'LHE_matched_muon_phi_1', 'LHE_matched_muon_eta_2', 'LHE_matched_muon_pt_2', 'LHE_matched_muon_phi_2', 'nele_lhe', 'nmuon_
# ...

# %% [markdown]
# ## Analyze the Leptons matched to the second LHE parton

# %%
h = out["variables"]["LHE_matched_ele_pt_1"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")


plt.legend()
#plt.yscale("log")
plt.xlabel("$p_T$ of Ele reco matched to LHE ele 1")
plt.xlim(0, 200)
# Out:
# (0.0, 200.0)

# %%
h = out["variables"]["LHE_matched_ele_eta_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")


plt.legend()
plt.xlabel("$\eta$ of Ele reco matched to LHE ele 2")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, '$\\eta$ of Ele reco matched to LHE ele 2')

# %%
h = out["variables"]["LHE_matched_muon_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel_dilep_notau", "year":"2018", "variation":"nominal"}], label="presel dilep notau")
# hep.histplot(h[{"cat":"presel_had", "year":"2018", "variation":"nominal"}], label="presel dilep onetau")
# hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
# hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
# hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
# hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
# hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
# hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")


plt.legend()
plt.xlabel("$p_T$ of Ele reco matched to LHE ele 2")

plt.xlim(0, 100)

print(np.sum(h[{"cat":"presel_dilep_notau", "year":"2018", "variation":"nominal"}].values()))
# Out:
# 20.469665030358694

# %%
h = out["variables"]["LHE_matched_ele_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")


plt.legend()
plt.xlabel("$p_T$ of Ele reco matched to LHE ele 2")

plt.xlim(0, 100)

print(np.sum(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}].values()))
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# 71.55163798815313

# %%
h = out["variables"]["LHE_matched_ele_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1mu", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1mu_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1mu_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1mu_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
hep.histplot(h[{"cat":"1mu_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")


plt.legend()
plt.xlabel("$p_T$ of Ele reco matched to LHE ele 2")

plt.xlim(0, 100)

print(np.sum(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}].values()))
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# 71.55163798815313

# %%
h = out["variables"]["LHE_matched_muon_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")


plt.legend()
plt.xlabel("$p_T$ of Ele reco matched to LHE ele 2")

plt.xlim(0, 100)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 100.0)

# %%
h = out["variables"]["LHE_matched_muon_eta_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1mu", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1mu_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1mu_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1mu_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
hep.histplot(h[{"cat":"1mu_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")

plt.legend()
plt.xlabel("$p_T$ of Ele reco matched to LHE ele 2")
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# Text(1, 0, '$p_T$ of Ele reco matched to LHE ele 2')

# %%
h = out["variables"]["LHE_matched_muon_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1mu", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1mu_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1mu_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1mu_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep no tau lhe")
hep.histplot(h[{"cat":"1mu_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep one tau lhe")

plt.legend()
plt.xlabel("$p_T$ of Ele reco matched to LHE ele 2")

plt.xlim(0, 100)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea4/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 100.0)

# %%
h = out["variables"]["LHE_matched_tau_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1lep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep notau lhe")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep onetau lhe")
hep.histplot(h[{"cat":"1lep_dilep_twotau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep twotau lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Ele matched LHE subleading pt")
plt.xlim(0, 200)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 200.0)

# %%
h = out["variables"]["LHE_matched_muon_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1lep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep notau lhe")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep onetau lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Ele matched LHE subleading pt")
plt.xlim(0, 200)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 200.0)

# %%
h = out["variables"]["LHE_matched_ele_pt_2"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1lep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1lep_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1lep_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1lep_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep notau lhe")
hep.histplot(h[{"cat":"1lep_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep onetau lhe")

plt.legend()
#plt.yscale("log")
plt.xlabel("Ele matched LHE subleading pt")
plt.xlim(0, 200)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# (0.0, 200.0)

# %%
h = out["variables"]["LHE_matched_ele_eta_2"]["ttHTobb"]

hep.histplot(h[{"cat":"semilep_presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
#plt.xlabel("Ele matched LHE subleading pt")
#plt.xlim(0, 200)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(

# %%
h = out["variables"]["lhe_matched_ele_1_mvaId"]["ttHTobb"]

hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep_notau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
#plt.xlabel("Ele matched LHE subleading pt")
#plt.xlim(0, 200)

# %%
h = out["variables"]["lhe_matched_ele_2_mvaId"]["ttHTobb"]

hep.histplot(h[{"cat":"presel_dilep", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")
hep.histplot(h[{"cat":"1ele_dilep_onetau", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
#plt.xlabel("Ele matched LHE subleading pt")
#plt.xlim(0, 200)
# Out:
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /work/dvalsecc/miniconda3/envs/coffea3/lib/python3.10/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(

# %%
h = out["variables"]["nele_lhe"]["ttHTobb"]

hep.histplot(h[{"cat":"semilep_presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
#plt.xlabel("Ele matched LHE subleading pt")
#plt.xlim(0, 200)

# %%
h = out["variables"]["nele_incl"]["ttHTobb"]

hep.histplot(h[{"cat":"semilep_presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
#plt.xlabel("Ele matched LHE subleading pt")
#plt.xlim(0, 200)

# %%
h = out["variables"]["nele_incl"]["ttHTobb"]

# hep.histplot(h[{"cat":"presel", "year":"2018", "variation":"nominal"}], label="semilep full presel")
# hep.histplot(h[{"cat":"presel_semilep", "year":"2018", "variation":"nominal"}], label="semilep pres + semilep LHE")
# hep.histplot(h[{"cat":"presel_dilep", "year":"2018", "variation":"nominal"}], label="semilep pres + dilep LHE")

hep.histplot(h[{"cat":"1ele", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV)")
hep.histplot(h[{"cat":"1ele_semilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - semilep lhe")
hep.histplot(h[{"cat":"1ele_dilep", "year":"2018", "variation":"nominal"}], label="1 ele reco (30 GeV) - dilep lhe")

plt.legend()
#plt.yscale("log")
#plt.xlabel("Ele matched LHE subleading pt")
plt.xlim(0, 4)
# Out:
# (0.0, 4.0)

# %%
out["variables"].keys()
# Out:
# dict_keys(['allEle_eta_1', 'allEle_pt_1', 'allEle_phi_1', 'allEle_eta_2', 'allEle_pt_2', 'allEle_phi_2', 'allMuon_eta_1', 'allMuon_pt_1', 'allMuon_phi_1', 'allMuon_eta_2', 'allMuon_pt_2', 'allMuon_phi_2', 'ElectronGood_eta_1', 'ElectronGood_pt_1', 'ElectronGood_phi_1', 'ElectronGood_eta_2', 'ElectronGood_pt_2', 'ElectronGood_phi_2', 'MuonGood_eta_1', 'MuonGood_pt_1', 'MuonGood_phi_1', 'MuonGood_eta_2', 'MuonGood_pt_2', 'MuonGood_phi_2', 'LHE_Electron_eta_1', 'LHE_Electron_pt_1', 'LHE_Electron_phi_1', 'LHE_Electron_eta_2', 'LHE_Electron_pt_2', 'LHE_Electron_phi_2', 'LHE_Muon_eta_1', 'LHE_Muon_pt_1', 'LHE_Muon_phi_1', 'LHE_Muon_eta_2', 'LHE_Muon_pt_2', 'LHE_Muon_phi_2', 'LHE_matched_ele_eta_1', 'LHE_matched_ele_pt_1', 'LHE_matched_ele_phi_1', 'LHE_matched_ele_eta_2', 'LHE_matched_ele_pt_2', 'LHE_matched_ele_phi_2', 'LHE_matched_muon_eta_1', 'LHE_matched_muon_pt_1', 'LHE_matched_muon_phi_1', 'LHE_matched_muon_eta_2', 'LHE_matched_muon_pt_2', 'LHE_matched_muon_phi_2', 'lhe_matched_ele_1_
# ...

# %% [markdown]
# # Number of leptons - scatter plot

# %%
H = out["variables"]["nlepLHE_nlepReco"]["ttHTobb"][{"variation":"nominal", "year":"2018"}]

# %%
H
# Out:
# Hist(
#   StrCategory(['1lep', '1lep_dilep_notau', '1lep_dilep_onetau', '1lep_semilep_notau', '2lep_dilep'], name='cat', label='Category'),
#   Integer(0, 6, name='events.nLHE_Lepton', label='Number of LHE Leptons'),
#   Integer(0, 6, name='events.nLHE_Electron', label='Number of LHE Electron'),
#   Integer(0, 6, name='events.nLHE_Muon', label='Number of LHE Muon'),
#   Integer(0, 6, name='events.nLHE_Tau', label='Number of LHE Tau'),
#   Integer(0, 6, name='events.nLeptonGood', label='Number of Lepton Good'),
#   Integer(0, 6, name='events.nElectronGood', label='Number of Lepton Good'),
#   Integer(0, 6, name='events.nMuonGood', label='Number of Lepton Good'),
#   storage=Weight()) # Sum: WeightedSum(value=6564.01, variance=12.2249)

# %%
hep.hist2dplot(H[{"cat":"1lep"}].project("events.nLHE_Lepton","events.nLeptonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
hep.hist2dplot(H[{"cat":"1lep"}].project("events.nLHE_Tau","events.nLeptonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
hep.hist2dplot(H[{"cat":"1lep"}].project("events.nLHE_Tau","events.nElectronGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
plt.ylabel("N. Electron good")
# Out:
# Text(0, 1, 'N. Electron good')

# %%
hep.hist2dplot(H[{"cat":"1lep"}].project("events.nLHE_Tau","events.nMuonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
plt.ylabel("N. Muon good")
# Out:
# Text(0, 1, 'N. Muon good')

# %%
hep.hist2dplot(H[{"cat":"1lep_semilep_notau"}].project("events.nLHE_Lepton","events.nLeptonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
hep.hist2dplot(H[{"cat":"1lep_dilep_onetau"}].project("events.nLHE_Lepton","events.nLeptonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
hep.hist2dplot(H[{"cat":"1lep_dilep_notau"}].project("events.nLHE_Lepton","events.nLeptonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
hep.hist2dplot(H[{"cat":"2lep_dilep"}].project("events.nLHE_Lepton","events.nLeptonGood"), cmin=1)
plt.ylim(0,4)
plt.xlim(0,4)
# Out:
# (0.0, 4.0)

# %% [markdown]
# Investigate the dilep sample

# %%
hep.hist2dplot(H[{"cat":"1lep_dilep_onetau"}].project("events.nLHE_Tau","events.nLeptonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
hep.hist2dplot(H[{"cat":"1lep_dilep_notau"}].project("events.nLHE_Tau","events.nLeptonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)

# %%
hep.hist2dplot(H[{"cat":"1lep_dilep_notau"}].project("events.nElectronGood","events.nMuonGood"), cmin=1)
plt.ylim(0,3)
plt.xlim(0,3)
# Out:
# (0.0, 3.0)
